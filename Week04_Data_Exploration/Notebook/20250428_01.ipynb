# %%
import pandas as pd

data = pd.read_csv('data.csv')
data
# Out:
#                                          Country Name Country Code  \
# 0                                           Argentina          ARG
# 1                                           Argentina          ARG
# 2                                           Argentina          ARG
# 3                                              Brazil          BRA
# 4                                              Brazil          BRA
# 5                                              Brazil          BRA
# 6                                               Chile          CHL
# 7                                               Chile          CHL
# 8                                               Chile          CHL
# 9                                            Paraguay          PRY
# 10                                           Paraguay          PRY
# 11                                           Paraguay          PRY
# 12                                            Uruguay          URY
# ...
